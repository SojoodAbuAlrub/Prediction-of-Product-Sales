# %% [markdown]
# <a href="https://colab.research.google.com/github/SojoodAbuAlrub/Prediction-of-Product-Sales/blob/main/Sales_Predictions_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading Data

# %%
import pandas as pd
import numpy as np

sales_predictions = ("/content/drive/MyDrive/AXSOSACADEMY (1)/01-Fundamentals/Week02/Data/sales_predictions_2023.csv")

df = pd.read_csv(sales_predictions)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# 1) How many rows and columns?
# 12 colomns, 8523 rows
#or by .shape
df.shape
# Out:
# (8523, 12)

# %%
#checking data type:

df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# #Cleaning Data

# %% [markdown]
# Duplicated Data

# %%
#Duplicated data:

duplicated_rows = df.duplicated()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Missing Values

# %%
#Searching about NA data

df.isna()
null_data= df.isna().sum()
null_data
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# the total number?

null_data= df.isna().sum().sum()
null_data
# Out:
# 3873

# %%
df.isna().sum() / len(df) * 100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
# Filling Item_Weight NA data
df['Item_Weight'] = df['Item_Weight'].fillna(value = 'Unknown')
df
# Out:
#      Item_Identifier Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.3          Low Fat         0.016047
# 1              DRC01        5.92          Regular         0.019278
# 2              FDN15        17.5          Low Fat         0.016760
# 3              FDX07        19.2          Regular         0.000000
# 4              NCD19        8.93          Low Fat         0.000000
# ...              ...         ...              ...              ...
# 8518           FDF22       6.865          Low Fat         0.056783
# 8519           FDS36        8.38          Regular         0.046982
# 8520           NCJ29        10.6          Low Fat         0.035186
# 8521           FDN46        7.21          Regular         0.145221
# 8522           DRG01        14.8          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#Filling Outlet_Size NA data
df['Outlet_Size'] = df['Outlet_Size'].fillna(value = 'Unknown')
df
# Out:
#      Item_Identifier Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.3          Low Fat         0.016047
# 1              DRC01        5.92          Regular         0.019278
# 2              FDN15        17.5          Low Fat         0.016760
# 3              FDX07        19.2          Regular         0.000000
# 4              NCD19        8.93          Low Fat         0.000000
# ...              ...         ...              ...              ...
# 8518           FDF22       6.865          Low Fat         0.056783
# 8519           FDS36        8.38          Regular         0.046982
# 8520           NCJ29        10.6          Low Fat         0.035186
# 8521           FDN46        7.21          Regular         0.145221
# 8522           DRG01        14.8          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#checking

df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# #Inconsistent categories of data

# %%
# addressing the unique data

string_cols = df.select_dtypes("object").columns
string_cols
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Type',
#        'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
# replacing data
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF':"Low Fat",'reg':'Regular' , "low fat": "Low Fat"})
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %% [markdown]
# #The summary statistics

# %%
#obtain the summary statistics of each numerical colomn (min, max, mean).

summary_stats = df.describe()
summary_stats
# Out:
#        Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count      8523.000000  8523.000000                8523.000000
# mean          0.066132   140.992782                1997.831867
# std           0.051598    62.275067                   8.371760
# min           0.000000    31.290000                1985.000000
# 25%           0.026989    93.826500                1987.000000
# 50%           0.053931   143.012800                1999.000000
# 75%           0.094585   185.643700                2004.000000
# max           0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800
